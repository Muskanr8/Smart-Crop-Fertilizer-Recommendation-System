# %%
# Clean previous clones if any
# !rm -rf Crop-and-fertilization

# Clone repo
# !git clone https://github.com/heypriyak/Crop-and-fertilization.git
# %cd Crop-and-fertilization

# Show repo files
# !ls -lah
# Out:
# Cloning into 'Crop-and-fertilization'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 29 (delta 9), reused 12 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 1.47 MiB | 18.41 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/Crop-and-fertilization
# total 1.2M
# drwxr-xr-x 4 root root 4.0K Dec 24 14:58  .
# drwxr-xr-x 1 root root 4.0K Dec 24 14:58  ..
# -rw-r--r-- 1 root root 762K Dec 24 14:58 'crop (1).ipynb'
# -rw-r--r-- 1 root root  909 Dec 24 14:58  crop.py
# drwxr-xr-x 2 root root 4.0K Dec 24 14:58  dataset
# -rw-r--r-- 1 root root 365K Dec 24 14:58  fertilizer.ipynb
# drwxr-xr-x 8 root root 4.0K Dec 24 14:58  .git
# -rw-r--r-- 1 root root   63 Dec 24 14:58  README.md

# %%
# !pip install -q numpy pandas matplotlib seaborn scikit-learn nbformat nbconvert

print("Dependencies installed successfully.")
# Out:
# Dependencies installed successfully.

# %%
# !jupyter nbconvert --to notebook --execute "fertilizer.ipynb" \
    --output "executed_fertilizer.ipynb" \
    --ExecutePreprocessor.timeout=600

# !echo "fertilizer.ipynb executed."
# Out:
# [NbConvertApp] Converting notebook fertilizer.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 405431 bytes to executed_fertilizer.ipynb
# fertilizer.ipynb executed.

# %%
# !jupyter nbconvert --to notebook --execute "crop (1).ipynb" \
    --output "executed_crop.ipynb" \
    --ExecutePreprocessor.timeout=900

# !echo "crop (1).ipynb executed."
# Out:
# [NbConvertApp] Converting notebook crop (1).ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 823959 bytes to executed_crop.ipynb
# crop (1).ipynb executed.

# %%
# !python crop.py || echo "Script finished (errors, if any, are shown above)."
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/CropFert_results

# !cp executed_fertilizer.ipynb /content/drive/MyDrive/CropFert_results/ 2>/dev/null || echo "fertilizer notebook not found"
# !cp executed_crop.ipynb /content/drive/MyDrive/CropFert_results/ 2>/dev/null || echo "crop notebook not found"

print("Executed notebooks copied to Drive → MyDrive/CropFert_results")
# Out:
# Mounted at /content/drive
# Executed notebooks copied to Drive → MyDrive/CropFert_results

# %%
# !cd/content/drive/MyDrive
# !zip -r CropFert_results.zip CropFert_results

# !echo "Zipped results available in MyDrive as CropFert_results.zip"
# Out:
# /bin/bash: line 1: cd/content/drive/MyDrive: No such file or directory
# 	zip warning: name not matched: CropFert_results
#
# zip error: Nothing to do! (try: zip -r CropFert_results.zip . -i CropFert_results)
# Zipped results available in MyDrive as CropFert_results.zip
